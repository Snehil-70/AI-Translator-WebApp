# %% [markdown]
# <a href="https://colab.research.google.com/github/Snehil-70/AI-Translator-WebApp/blob/main/translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(
    'welcome in google colab'
)
# Out:
# welcome in google colab

# %%
#create language translation using hugging face from transformers
from transformers import MarianMTModel, MarianTokenizer
#to select the model name from hugging face transformers
model_name = 'Helsinki-NLP/opus-mt-en-hi'
#to load the model using modelname
model = MarianMTModel.from_pretrained(model_name)
#to load the tokenizer using modelname
tokenizer = MarianTokenizer.from_pretrained(model_name)
#to get the input text from user to translate
prompt = input('enter the text to translate')
#to encode the input text into input tokensusing tokenizer
input_tokens = tokenizer(prompt,return_tensors='pt',padding = True)
#to generate the output tokensmusing model and input tokens
output_tokens = model.generate(**input_tokens)
#to decode the output tokens into translated text
print(tokenizer.decode(output_tokens[0],skip_special_tokens=True))
#upload the code to github

# %%
#speexh to text convert using whisper model
# !pip install openai-whisper
# !apt install -y ffmpeg
import whisper
from google.colab import files

model = whisper.load_model("base")

uploaded =  files.upload()
audio = list(uploaded.keys())[0]

result = model.transcribe(audio, fp16 = False)

print(result["text"])
